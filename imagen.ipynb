# %% [markdown]
# <a href="https://colab.research.google.com/github/gab69/restauracion_imagenes/blob/main/imagen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Cambia al directorio base
# %cd /content

# Elimina el directorio GFPGAN si existe y clona el repositorio
# !rm -rf GFPGAN
# !git clone https://github.com/TencentARC/GFPGAN.git
# %cd GFPGAN

# Instala las dependencias
# !pip install basicsr facexlib -r requirements.txt
# !python setup.py develop
# !pip install realesrgan

# Descarga el modelo preentrenado
pretrained_model_url = "https://github.com/TencentARC/GFPGAN/releases/download/v1.3.0/GFPGANv1.4.pth"
pretrained_model_path = "experiments/pretrained_models/GFPGANv1.4.pth"
# !wget {pretrained_model_url} -P {pretrained_model_path}
# Out:
# /content
# Cloning into 'GFPGAN'...
# remote: Enumerating objects: 523, done.
# remote: Counting objects: 100% (251/251), done.
# remote: Compressing objects: 100% (58/58), done.
# remote: Total 523 (delta 209), reused 193 (delta 193), pack-reused 272
# Receiving objects: 100% (523/523), 5.37 MiB | 18.72 MiB/s, done.
# Resolving deltas: 100% (280/280), done.
# /content/GFPGAN
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 172.5/172.5 kB 2.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.6/59.6 kB 5.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 299.2/299.2 kB 9.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 25.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 254.7/254.7 kB 21.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.0/178.0 kB 18.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...

# %%
# Configuración para cargar imágenes
import os
from google.colab import files
import shutil

upload_folder = 'inputs/upload'
shutil.rmtree(upload_folder, ignore_errors=True)
os.makedirs(upload_folder)

# Sube las imágenes
uploaded = files.upload()
for filename in uploaded.keys():
    dst_path = os.path.join(upload_folder, filename)
    print(f'move {filename} to {dst_path}')
    shutil.move(filename, dst_path)

# Realiza la inferencia
# !rm -rf results
# !python inference_gfpgan.py -i inputs/upload -o results -v 1.4 -s 2 --bg_upsampler realesrgan

# Descarga los resultados comprimidos
print('Download results')
os.system('zip -r download.zip results')
files.download("download.zip")
# Out:
#      <input type="file" id="files-f5c69cd6-1353-43c6-83af-45820c6d7fba" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f5c69cd6-1353-43c6-83af-45820c6d7fba">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
